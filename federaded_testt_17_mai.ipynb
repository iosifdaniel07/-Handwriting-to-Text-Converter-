# %% [markdown]
# <a href="https://colab.research.google.com/github/iosifdaniel07/-Handwriting-to-Text-Converter-/blob/main/federaded_testt_17_mai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import copy
from sklearn.model_selection import train_test_split

from google.colab import files
# !pip install gdown

from google.colab import files
# !pip install -U --no-cache-dir gdown --pre
from google.colab import drive
drive.mount('/content/drive')
#!ls /content/drive/MyDrive
# !cp "/content/drive/MyDrive/data_set_normalize_c.csv" .

import numpy as np
import pandas as pd
import gdown
import seaborn as sns
import matplotlib.pyplot as plt
from keras import Sequential
from keras.src.layers import LSTM, Dropout, Dense
from keras.src.utils import to_categorical
from keras.src.optimizers import Adam, RMSprop, Nadam
from keras.src.metrics import AUC
from keras.src.regularizers import L2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.metrics import AUC
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# 1. Încarcă și preprocesează datele
data_set = pd.read_csv('data_set_normalize_c.csv')
data_set.replace([np.inf, -np.inf], np.nan, inplace=True)
data_set.fillna(data_set.median(), inplace=True)

cols_to_drop = [
    'ECE Flag Count',
    'RST Flag Count',
    'Fwd URG Flags',
    'CWE Flag Count',
    'Fwd PSH Flags',
    'Fwd Header Length.1',
    'Idle Std',
    'Down/Up Ratio',
    'Active Max',
    'Active Min',
    'Subflow Bwd Bytes',
    'Active Max',
    'Subflow Bwd Packets',
    'Subflow Fwd Packets',
    'Total Backward Packets',
    'Fwd IAT Std',
    'Active Mean',
    'act_data_pkt_fwd',
    'Total Length of Fwd Packets',
    'Total Fwd Packets'
]

X = data_set.drop(columns=['Label'])
#X = data_set.drop(columns=cols_to_drop)
y = data_set['Label']

timesteps = 5

def create_sequences(data, labels, timesteps=5):
    X_seq, y_seq = [], []
    for i in range(len(data) - timesteps):
        X_seq.append(data[i:i + timesteps])
        y_seq.append(labels[i + timesteps - 1])
    return np.array(X_seq), np.array(y_seq)

X_seq_all, y_seq_all = create_sequences(X, y, timesteps)
X_seq_all = X_seq_all.astype(np.float32)
y_seq_all = y_seq_all.astype(np.int64)

# 2. Împarte datele în train (80%) și validare (20%)
X_train_initial, X_val, y_train_initial, y_val = train_test_split(
    X_seq_all, y_seq_all, test_size=0.2, random_state=42, shuffle=True
)

#data train big model
X_train, X_train_bm, y_train, y_train_bm = train_test_split(
    X_train_initial, y_train_initial, test_size=0.1, random_state=42, shuffle=True
)

print("X_train shape - shared models :", X_train.shape)
print("x_train shape - big model:", X_train_bm.shape)
print("x_train shape - validation:", X_val.shape)

# 3. Definește modelul
def create_keras_model_v4():
    model = Sequential([
        LSTM(128, return_sequences=True, input_shape=(timesteps, X_train.shape[2]) ),
        Dropout(0.3),
        LSTM(64, return_sequences=False),
        Dropout(0.3),
        Dense(100, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(loss=BinaryCrossentropy(), optimizer=Nadam(), metrics=[AUC(name='auc')])
    return model

early_stopping = EarlyStopping(monitor='loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.001, patience=3, verbose=1)
checkpoint = ModelCheckpoint('best_model.h5', monitor='loss', save_best_only=True, verbose=1)

global_model = create_keras_model_v4()

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

def evaluate_and_plot_model(model, history, X_test, y_test, labels=['Normal', 'Anomaly']):

    # -- Plot training history
    plt.figure(figsize=(14, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss', color='blue')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # AUC or Accuracy
    plt.subplot(1, 2, 2)
    if 'auc' in history.history:
        plt.plot(history.history['auc'], label='Training AUC', color='green')
        if 'val_auc' in history.history:
            plt.plot(history.history['val_auc'], label='Validation AUC', color='red')
        plt.ylabel('AUC')
        plt.title('AUC over Epochs')
    elif 'accuracy' in history.history:
        plt.plot(history.history['accuracy'], label='Training Accuracy', color='green')
        if 'val_accuracy' in history.history:
            plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
        plt.ylabel('Accuracy')
        plt.title('Accuracy over Epochs')
    else:
        plt.title('No Accuracy/AUC Found')

    plt.xlabel('Epochs')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # -- Evaluate the model
    loss, metric = global_model.evaluate(X_val, y_val, verbose=1)
    print(f"\nTest Loss: {loss:.4f}")
    print(f"Test Metric (Accuracy/AUC): {metric:.4f}")

    # -- Predict and analyze results
    y_pred_probs = model.predict(X_test)
    y_pred_classes = (y_pred_probs > 0.5).astype(int).reshape(-1)

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred_classes, target_names=labels))

    # -- Confusion Matrix
    cm = confusion_matrix(y_test, y_pred_classes)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

history = global_model.fit(
    X_train_bm, y_train_bm,
    epochs=25,
    batch_size=128,
    callbacks=[early_stopping, reduce_lr, checkpoint],
    validation_split=0.2,
    verbose=1
)

evaluate_and_plot_model(global_model, history, X_val, y_val)

import numpy as np

# 4. Setări FL
NUM_CLIENTS = 10
ROUNDS = 2
BATCH_SIZE = 128
split_size = len(X_train) // NUM_CLIENTS

# 5. Împarte datele de antrenare în datasets pe client
client_datasets = []
client_labels = []
for i in range(NUM_CLIENTS):
    start = i * split_size
    end = (i + 1) * split_size
    client_datasets.append(X_train[start:end])
    client_labels.append(y_train[start:end])

# 6. Inițializează modelul global
global_weights = global_model.get_weights()

# 7. Simulează runde federate
for round_num in range(ROUNDS):
    print(f"\n--- Federated Round {round_num+1} ---")
    local_weights = []

    for X_client, y_client in zip(client_datasets, client_labels):
        client_model = create_keras_model_v4()
        client_model.set_weights(copy.deepcopy(global_weights))

        client_history = client_model.fit(
                          X_client,
                          y_client,
                          epochs=10,
                          batch_size=128,
                          callbacks=[early_stopping, reduce_lr, checkpoint],
                          validation_split=0.2,
                          verbose=1
                        )
        evaluate_and_plot_model(client_model, client_history, X_val, y_val)
        local_weights.append(client_model.get_weights())

    # Agregare (medie simplă)
    new_weights = []
    for weights in zip(*local_weights):
        new_weights.append(np.mean(np.array(weights), axis=0))

    global_weights = new_weights
    global_model.set_weights(global_weights)

    evaluate_and_plot_model(global_model, history, X_val, y_val)

# 8. Evaluare finală pe datele de validare (cele 20%)
evaluate_and_plot_model(global_model, history, X_val, y_val)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# X_train shape - shared models : (2112934, 5, 76)
# x_train shape - big model: (234771, 5, 76)
# x_train shape - validation: (586927, 5, 76)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9743 - loss: 0.1051
# Epoch 1: loss improved from inf to 0.05257, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - auc: 0.9743 - loss: 0.1050 - val_auc: 0.9976 - val_loss: 0.0205 - learning_rate: 0.0010
# Epoch 2/25
# 1466/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9982 - loss: 0.0167
# Epoch 2: loss improved from 0.05257 to 0.01549, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9982 - loss: 0.0167 - val_auc: 0.9979 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 3/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9987 - loss: 0.0116
# Epoch 3: loss improved from 0.01549 to 0.01085, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9987 - loss: 0.0116 - val_auc: 0.9983 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 4/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9985 - loss: 0.0092
# Epoch 4: loss improved from 0.01085 to 0.00920, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9985 - loss: 0.0092 - val_auc: 0.9984 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 5/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9990 - loss: 0.0079
# Epoch 5: loss improved from 0.00920 to 0.00785, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9990 - loss: 0.0079 - val_auc: 0.9985 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 6/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9991 - loss: 0.0073
# Epoch 6: loss improved from 0.00785 to 0.00669, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - auc: 0.9991 - loss: 0.0073 - val_auc: 0.9996 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 7/25
# 1466/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9994 - loss: 0.0062
# Epoch 7: loss improved from 0.00669 to 0.00614, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9994 - loss: 0.0062 - val_auc: 0.9995 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 8/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9995 - loss: 0.0063
# Epoch 8: loss improved from 0.00614 to 0.00573, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9995 - loss: 0.0063 - val_auc: 0.9994 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 9/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9996 - loss: 0.0056
# Epoch 9: loss improved from 0.00573 to 0.00540, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9996 - loss: 0.0056 - val_auc: 0.9998 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 10/25
# 1466/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0043
# Epoch 10: loss improved from 0.00540 to 0.00460, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9998 - loss: 0.0043 - val_auc: 0.9993 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 11/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9995 - loss: 0.0046
# Epoch 11: loss did not improve from 0.00460
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9995 - loss: 0.0046 - val_auc: 0.9996 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 12/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9997 - loss: 0.0042
# Epoch 12: loss improved from 0.00460 to 0.00436, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9997 - loss: 0.0042 - val_auc: 0.9997 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 13/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0043
# Epoch 13: loss improved from 0.00436 to 0.00419, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9998 - loss: 0.0043 - val_auc: 0.9996 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 14/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0036
# Epoch 14: loss improved from 0.00419 to 0.00389, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9998 - loss: 0.0036 - val_auc: 0.9996 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 15/25
# 1466/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0036
# Epoch 15: loss improved from 0.00389 to 0.00374, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9998 - loss: 0.0036 - val_auc: 0.9996 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 16/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0035
# Epoch 16: loss improved from 0.00374 to 0.00368, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9998 - loss: 0.0035 - val_auc: 0.9997 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 17/25
# 1467/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0033
# Epoch 17: loss improved from 0.00368 to 0.00337, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - auc: 0.9998 - loss: 0.0033 - val_auc: 0.9997 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 18/25
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9997 - loss: 0.0041
# Epoch 18: loss improved from 0.00337 to 0.00334, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - auc: 0.9997 - loss: 0.0041 - val_auc: 0.9997 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 19/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9997 - loss: 0.0034
# Epoch 19: loss improved from 0.00334 to 0.00323, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - auc: 0.9997 - loss: 0.0034 - val_auc: 0.9996 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 20/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0030
# Epoch 20: loss improved from 0.00323 to 0.00312, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - auc: 0.9998 - loss: 0.0030 - val_auc: 0.9996 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 21/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9998 - loss: 0.0032
# Epoch 21: loss did not improve from 0.00312
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - auc: 0.9998 - loss: 0.0032 - val_auc: 0.9996 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 22/25
# 1467/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0031
# Epoch 22: loss improved from 0.00312 to 0.00293, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - auc: 0.9998 - loss: 0.0031 - val_auc: 0.9996 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 23/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0031
# Epoch 23: loss did not improve from 0.00293
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - auc: 0.9998 - loss: 0.0031 - val_auc: 0.9997 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 24/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 24: loss improved from 0.00293 to 0.00276, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9996 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 25/25
# 1465/1468 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 25: loss did not improve from 0.00276
# 1468/1468 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9996 - val_loss: 0.0035 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 62s 3ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 51s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# --- Federated Round 1 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9997 - loss: 0.0042
# Epoch 1: loss did not improve from 0.00276
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - auc: 0.9997 - loss: 0.0042 - val_auc: 0.9998 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 2/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0031
# Epoch 2: loss did not improve from 0.00276
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0031 - val_auc: 1.0000 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 3/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0033
# Epoch 3: loss did not improve from 0.00276
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0033 - val_auc: 0.9999 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 4/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0027
# Epoch 4: loss improved from 0.00276 to 0.00276, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0027 - val_auc: 0.9997 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0037
# Epoch 5: loss did not improve from 0.00276
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0037 - val_auc: 0.9998 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 6/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 6: loss improved from 0.00276 to 0.00271, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9998 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 7/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0027
# Epoch 7: loss improved from 0.00271 to 0.00257, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0027 - val_auc: 0.9998 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 8/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0029
# Epoch 8: loss did not improve from 0.00257
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0029 - val_auc: 0.9998 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 9/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0023
# Epoch 9: loss improved from 0.00257 to 0.00243, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9999 - loss: 0.0023 - val_auc: 0.9996 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 10/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0020
# Epoch 10: loss improved from 0.00243 to 0.00217, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0020 - val_auc: 0.9999 - val_loss: 0.0029 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 63s 3ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 52s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9997 - loss: 0.0042
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - auc: 0.9997 - loss: 0.0042 - val_auc: 0.9998 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 2/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9997 - loss: 0.0035
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - auc: 0.9997 - loss: 0.0035 - val_auc: 1.0000 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 3/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9999 - loss: 0.0031
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - auc: 0.9999 - loss: 0.0031 - val_auc: 0.9999 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 4/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9997 - loss: 0.0032
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9997 - loss: 0.0032 - val_auc: 1.0000 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9999 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 6/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 1.0000 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 7/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9999 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 8/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9998 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 9/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9999 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 10/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9999 - val_loss: 0.0032 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 58s 3ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 51s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9997 - loss: 0.0042
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - auc: 0.9997 - loss: 0.0042 - val_auc: 0.9999 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 2/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0032
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0032 - val_auc: 0.9999 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 3/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0036
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0036 - val_auc: 0.9999 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 4/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0032
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0032 - val_auc: 0.9998 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 5/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0034
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0034 - val_auc: 0.9999 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 6/10
# 1317/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9998 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 7/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0024
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0024 - val_auc: 0.9999 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 8/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0024
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0024 - val_auc: 0.9999 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 9/10
# 1317/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9999 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 10/10
# 1317/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9999 - loss: 0.0024
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - auc: 0.9999 - loss: 0.0024 - val_auc: 0.9999 - val_loss: 0.0024 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 57s 3ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 47s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9996 - loss: 0.0041
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - auc: 0.9996 - loss: 0.0041 - val_auc: 0.9994 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 2/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0032
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0032 - val_auc: 0.9995 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 3/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0036
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0036 - val_auc: 0.9994 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 4/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0033
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0033 - val_auc: 0.9995 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0028
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9998 - loss: 0.0028 - val_auc: 0.9996 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 6/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0030
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0030 - val_auc: 0.9995 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 7/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9995 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 8/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0029
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9998 - loss: 0.0029 - val_auc: 0.9996 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 9/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0025
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0025 - val_auc: 0.9995 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 10/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0023
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0023 - val_auc: 0.9995 - val_loss: 0.0048 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 65s 4ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 56s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9997 - loss: 0.0041
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - auc: 0.9997 - loss: 0.0041 - val_auc: 0.9999 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 2/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0043
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0043 - val_auc: 0.9998 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 3/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0034
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0034 - val_auc: 0.9998 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 4/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9998 - loss: 0.0035
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - auc: 0.9998 - loss: 0.0035 - val_auc: 0.9998 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9999 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 6/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9999 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 7/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9998 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 8/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0029
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0029 - val_auc: 0.9998 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 9/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0030
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9999 - loss: 0.0030 - val_auc: 0.9998 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 10/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0024
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0024 - val_auc: 0.9997 - val_loss: 0.0029 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 72s 4ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 58s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9997 - loss: 0.0038
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - auc: 0.9997 - loss: 0.0038 - val_auc: 0.9999 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 2/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0038
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9998 - loss: 0.0038 - val_auc: 0.9997 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 3/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0033
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9998 - loss: 0.0033 - val_auc: 0.9999 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 4/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0030
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0030 - val_auc: 0.9998 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0027
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0027 - val_auc: 0.9998 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 6/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0032
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9998 - loss: 0.0032 - val_auc: 0.9997 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 7/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9998 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 8/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0029
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
#
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0029 - val_auc: 0.9999 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 9/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9999 - val_loss: 0.0031 - learning_rate: 1.0000e-06
# Epoch 10/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9999 - loss: 0.0021
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - auc: 0.9999 - loss: 0.0021 - val_auc: 0.9999 - val_loss: 0.0031 - learning_rate: 1.0000e-06
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 71s 4ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 56s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9998 - loss: 0.0039
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - auc: 0.9998 - loss: 0.0039 - val_auc: 0.9998 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 2/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0036
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - auc: 0.9999 - loss: 0.0036 - val_auc: 0.9998 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 3/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0028
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - auc: 0.9998 - loss: 0.0028 - val_auc: 0.9998 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 4/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9999 - loss: 0.0032
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - auc: 0.9999 - loss: 0.0032 - val_auc: 0.9998 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 5/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9999 - loss: 0.0029
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - auc: 0.9999 - loss: 0.0029 - val_auc: 0.9997 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 6/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0032
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9999 - loss: 0.0032 - val_auc: 0.9998 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 7/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 1.0000 - loss: 0.0026
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 1.0000 - loss: 0.0026 - val_auc: 0.9997 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 8/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9997 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 9/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9997 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 10/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0027
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9999 - loss: 0.0027 - val_auc: 0.9996 - val_loss: 0.0025 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 68s 4ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 58s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9996 - loss: 0.0036
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - auc: 0.9996 - loss: 0.0036 - val_auc: 0.9997 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 2/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9998 - loss: 0.0035
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - auc: 0.9998 - loss: 0.0035 - val_auc: 0.9997 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 3/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9997 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 4/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0027
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9998 - loss: 0.0027 - val_auc: 0.9994 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9997 - loss: 0.0036
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9997 - loss: 0.0036 - val_auc: 0.9996 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 6/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0024
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9998 - loss: 0.0024 - val_auc: 0.9997 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 7/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0021
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0021 - val_auc: 0.9996 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 8/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0027
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0027 - val_auc: 0.9993 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 9/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9997 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 10/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9999 - loss: 0.0022
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
#
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - auc: 0.9999 - loss: 0.0022 - val_auc: 0.9995 - val_loss: 0.0048 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 65s 4ms/step - auc: 0.9998 - loss: 0.0035
#
# Test Loss: 0.0035
# Test Metric (Accuracy/AUC): 0.9998
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 56s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0040
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - auc: 0.9998 - loss: 0.0040 - val_auc: 0.9999 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 2/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0033
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0033 - val_auc: 0.9999 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 3/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0034
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0034 - val_auc: 1.0000 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 4/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0031
# Epoch 4: loss did not improve from 0.00217
# ...
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0031
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - auc: 0.9998 - loss: 0.0031 - val_auc: 0.9997 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 2/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9997 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 3/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0032
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0032 - val_auc: 0.9996 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 4/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0027
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0027 - val_auc: 0.9998 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9997 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 6/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0027
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0027 - val_auc: 0.9997 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 7/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0022
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0022 - val_auc: 0.9998 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 8/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 1.0000 - loss: 0.0022
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 1.0000 - loss: 0.0022 - val_auc: 0.9997 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 9/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0028
# Epoch 9: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0028 - val_auc: 0.9996 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 10/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0024
# Epoch 10: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0024 - val_auc: 0.9997 - val_loss: 0.0027 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 64s 3ms/step - auc: 0.9999 - loss: 0.0028
#
# Test Loss: 0.0027
# Test Metric (Accuracy/AUC): 0.9999
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 55s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0029
# Epoch 1: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - auc: 0.9998 - loss: 0.0029 - val_auc: 0.9998 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 2/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 2: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9998 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 3/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0024
# Epoch 3: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9999 - loss: 0.0024 - val_auc: 0.9999 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 4/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 4: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9997 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0020
# Epoch 5: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0020 - val_auc: 0.9998 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 6/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0022
# Epoch 6: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0022 - val_auc: 0.9998 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 7/10
# 1318/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0022
# Epoch 7: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0022 - val_auc: 0.9997 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 8/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0025
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
#
# Epoch 8: loss did not improve from 0.00217
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0025 - val_auc: 0.9994 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 9/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0018
# Epoch 9: loss improved from 0.00217 to 0.00200, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0018 - val_auc: 0.9994 - val_loss: 0.0046 - learning_rate: 1.0000e-06
# Epoch 10/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0019
# Epoch 10: loss improved from 0.00200 to 0.00199, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - auc: 0.9999 - loss: 0.0019 - val_auc: 0.9994 - val_loss: 0.0046 - learning_rate: 1.0000e-06
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 63s 3ms/step - auc: 0.9999 - loss: 0.0028
#
# Test Loss: 0.0027
# Test Metric (Accuracy/AUC): 0.9999
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0030
# Epoch 1: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - auc: 0.9999 - loss: 0.0030 - val_auc: 0.9999 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 2/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0030
# Epoch 2: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0030 - val_auc: 1.0000 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 3/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0030
# Epoch 3: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0030 - val_auc: 1.0000 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 4/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0028
# Epoch 4: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0028 - val_auc: 0.9999 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 5/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0020
# Epoch 5: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0020 - val_auc: 0.9998 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 6/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9998 - loss: 0.0027
# Epoch 6: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0027 - val_auc: 1.0000 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 7/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 7: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9998 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 8/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0022
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
#
# Epoch 8: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0022 - val_auc: 0.9998 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 9/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9999 - loss: 0.0022
# Epoch 9: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0022 - val_auc: 0.9998 - val_loss: 0.0030 - learning_rate: 1.0000e-06
# Epoch 10/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 1.0000 - loss: 0.0022
# Epoch 10: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 1.0000 - loss: 0.0022 - val_auc: 0.9998 - val_loss: 0.0029 - learning_rate: 1.0000e-06
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 64s 3ms/step - auc: 0.9999 - loss: 0.0028
#
# Test Loss: 0.0027
# Test Metric (Accuracy/AUC): 0.9999
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0029
# Epoch 1: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - auc: 0.9998 - loss: 0.0029 - val_auc: 0.9998 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 2/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 2: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9997 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 3/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9998 - loss: 0.0024
# Epoch 3: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - auc: 0.9998 - loss: 0.0024 - val_auc: 0.9998 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 4/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0024
# Epoch 4: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0024 - val_auc: 0.9997 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 5/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0017
# Epoch 5: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0017 - val_auc: 0.9999 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 6/10
# 1319/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0023
# Epoch 6: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0023 - val_auc: 0.9999 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 7/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0026
# Epoch 7: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0026 - val_auc: 0.9997 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 8/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0023
# Epoch 8: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0023 - val_auc: 0.9996 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 9/10
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9999 - loss: 0.0021
# Epoch 9: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - auc: 0.9999 - loss: 0.0021 - val_auc: 0.9997 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 10/10
# 1320/1321 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9999 - loss: 0.0021
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
#
# Epoch 10: loss did not improve from 0.00199
# 1321/1321 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - auc: 0.9999 - loss: 0.0021 - val_auc: 0.9998 - val_loss: 0.0031 - learning_rate: 0.0010
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 71s 4ms/step - auc: 0.9999 - loss: 0.0028
#
# Test Loss: 0.0027
# Test Metric (Accuracy/AUC): 0.9999
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 56s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 68s 4ms/step - auc: 0.9999 - loss: 0.0027
#
# Test Loss: 0.0025
# Test Metric (Accuracy/AUC): 0.9999
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 57s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 64s 3ms/step - auc: 0.9999 - loss: 0.0027
#
# Test Loss: 0.0025
# Test Metric (Accuracy/AUC): 0.9999
# 18342/18342 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00    475537
#      Anomaly       1.00      1.00      1.00    111390
#
#     accuracy                           1.00    586927
#    macro avg       1.00      1.00      1.00    586927
# weighted avg       1.00      1.00      1.00    586927
